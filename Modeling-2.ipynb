# %%
# Imports and environment setup
import random
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from scipy import sparse

import matplotlib.pyplot as plt
import seaborn as sns

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
random.seed(RANDOM_SEED)

# %% [markdown]
# Our dataset:
#
# https://www.kaggle.com/datasets/victorsoeiro/netflix-tv-shows-and-movies

# %%
df = pd.read_csv("titles_cleaned.csv")

# %%
numeric_cols = df.select_dtypes(include=['number']).columns
numeric_cols
# Out:
# Index(['release_year', 'runtime', 'seasons', 'imdb_score', 'imdb_votes',
#        'tmdb_popularity', 'tmdb_score'],
#       dtype='object')

# %%
from sklearn.preprocessing import MultiLabelBinarizer

df['genres_list'] = df['genres'].str.split(', ')

mlb = MultiLabelBinarizer()
genre_dummies = pd.DataFrame(mlb.fit_transform(df['genres_list']),
                             columns=mlb.classes_,
                             index=df.index)

df = pd.concat([df, genre_dummies], axis=1)

# %%
tfidf = TfidfVectorizer(stop_words='english', max_features=5000)
tfidf_description = tfidf.fit_transform(df['description'])

from scipy.sparse import hstack
combined_features = hstack([tfidf_description, genre_dummies])

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity_matrix = cosine_similarity(combined_features)

# %%
def top_rated_by_genres_all(genres, df, n=10):
    
    if isinstance(genres, str):
        genres = [g.strip().lower() for g in genres.split(",")]
    else:
        genres = [g.lower() for g in genres]
    
    
    col = df['genre_string'].fillna("").astype(str).str.lower()

    
    mask = col.apply(lambda x: all(g in x for g in genres))
    
    genre_df = df[mask]

    if genre_df.empty:
        return f"No titles found containing ALL genres: {genres}"

    top = genre_df.sort_values(by='imdb_score', ascending=False)

    return top[['title', 'genres', 'imdb_score', 'description']].head(n)

# %%
top_rated_by_genres_all("Action", df)
# Out:
#                            title  \
# 233   Avatar: The Last Airbender
# 4770                       Major
# 4717                      Arcane
# 835              Attack on Titan
# 653              Hunter x Hunter
# 103                 Cowboy Bebop
# 3217                 The Untamed
# 3048                Vinland Saga
# 100                    One Piece
# 237                    Inception
#
#                                                  genres  imdb_score  \
# 233   ['scifi', 'animation', 'action', 'family', 'fa...         9.3
# 4770                                ['action', 'drama']         9.1
# 4717  ['scifi', 'action', 'drama', 'animation', 'fan...         9.0
# 835   ['action', 'scifi', 'animation', 'horror', 'dr...         9.0
# 653        ['action', 'animation', 'comedy', 'fantasy']         9.0
# 103   ['animation', 'action', 'scifi', 'western', 'c...         8.9
# 3217  ['action', 'drama', 'thriller', 'romance', 'co...         8.8
# 3048  ['animation', 'action', 'drama', 'war', 'histo...         8.8
# 100   ['animation', 'action', 'comedy', 'drama', 'fa...         8.8
# 237            ['action', 'scifi', 'music', 'thriller']         8.8
#
#                                             description
# 233   In a war-torn world of elemental magic, a youn...
# 4770  Based on the life of real-life Hero Major Sand...
# 4717  Amid the stark discord of twin cities Piltover...
# 835   Several hundred years ago, humans were nearly ...
# 653   Twelve-year-old Gon Freecss one day discovers ...
# 103   In 2071, roughly fifty years after an accident...
# 3217  In a land dominated by the mighty Wen clan, a ...
# 3048  For a thousand years, the Vikings have made qu...
# 100   Years ago, the fearsome Pirate King, Gol D. Ro...
# 237   Cobb, a skilled thief who commits corporate es...

# %%
def recommend(title, df, similarity_matrix, n=10):
   
    title = title.lower()
    
   
    matches = df.index[df['title_lower'] == title]

    if len(matches) == 0:
        return f"Title '{title}' not found."

    idx = matches[0]

    
    scores = list(enumerate(similarity_matrix[idx]))
    scores = sorted(scores, key=lambda x: x[1], reverse=True)

    
    top_indices = [i for i, score in scores[1:n+1]]

    return df.iloc[top_indices][['title', 'genres', 'description']]

df['title_lower'] = df['title'].str.lower()

# %%
recommend("Stranger Things", df, similarity_matrix)
# Out:
#               title                                             genres  \
# 3208      The Order  ['scifi', 'drama', 'thriller', 'fantasy', 'hor...
# 2191          GHOUL  ['scifi', 'drama', 'thriller', 'fantasy', 'hor...
# 5132  The Privilege           ['scifi', 'thriller', 'drama', 'horror']
# 1188         Glitch           ['scifi', 'thriller', 'drama', 'horror']
# 4846  Choose or Die           ['scifi', 'thriller', 'drama', 'horror']
# 836   The Originals            ['scifi', 'drama', 'fantasy', 'horror']
# 1855    Nightflyers           ['scifi', 'thriller', 'drama', 'horror']
# 1939      The Titan  ['scifi', 'thriller', 'fantasy', 'drama', 'rom...
# 3092   Black Summer  ['scifi', 'thriller', 'action', 'drama', 'horr...
# 3196       The Call  ['scifi', 'thriller', 'drama', 'crime', 'horror']
#
#                                             description
# 3208  Out to avenge his mother's death, a college st...
# 2191  A newly minted military interrogator arrives a...
# 5132  A wealthy teen and his friends attending an el...
# 1188  A police officer and a doctor face an emotiona...
# 4846  In pursuit of an unclaimed $125,000 prize, a b...
# 836   A spin-off from The Vampire Diaries and set in...
# 1855  In the year 2093, a team of scientists aboard ...
# 1939  On a bleak future Earth, a soldier endures a r...
# 3092  In the dark, early days of a zombie apocalypse...
# 3196  Connected by phone in the same home but 20 yea...

# %%
def hybrid_weighted_recommend(title, df, similarity_matrix, n=10):
    if 'title_lower' not in df.columns:
        df['title_lower'] = df['title'].str.lower()
    
    title = title.lower()
    matches = df.index[df['title_lower'] == title]
    if len(matches) == 0:
        return f"Title '{title}' not found."
    
    idx = matches[0]
    sim_scores = similarity_matrix[idx]
    
    R = df['imdb_score'].fillna(0)
    v = df['imdb_votes'].fillna(0)
    C = R.mean()
    m = np.percentile(v, 80)
    
    weighted_imdb = (v/(v + m)) * R + (m/(v + m)) * C
    weighted_norm = (weighted_imdb - weighted_imdb.min()) / (weighted_imdb.max() - weighted_imdb.min())
    
    hybrid_scores = 0.7 * sim_scores + 0.3 * weighted_norm
    
    scores = list(enumerate(hybrid_scores))
    scores = sorted(scores, key=lambda x: x[1], reverse=True)
    top_indices = [i for i, s in scores[1:n+1]]

    return df.iloc[top_indices][['title', 'genres', 'imdb_score', 'imdb_votes', 'description']]

# %%
hybrid_weighted_recommend("Stranger Things", df, similarity_matrix, n=10)
# Out:
#                      title                                             genres  \
# 836          The Originals            ['scifi', 'drama', 'fantasy', 'horror']
# 3208             The Order  ['scifi', 'drama', 'thriller', 'fantasy', 'hor...
# 2191                 GHOUL  ['scifi', 'drama', 'thriller', 'fantasy', 'hor...
# 1188                Glitch           ['scifi', 'thriller', 'drama', 'horror']
# 5132         The Privilege           ['scifi', 'thriller', 'drama', 'horror']
# 3196              The Call  ['scifi', 'thriller', 'drama', 'crime', 'horror']
# 1855           Nightflyers           ['scifi', 'thriller', 'drama', 'horror']
# 3046  Love, Death & Robots  ['scifi', 'animation', 'thriller', 'horror', '...
# 3092          Black Summer  ['scifi', 'thriller', 'action', 'drama', 'horr...
# 219           Supernatural  ['scifi', 'horror', 'thriller', 'drama', 'fant...
#
#       imdb_score  imdb_votes  \
# 836          8.3    133406.0
# 3208         6.7     27943.0
# 2191         8.0         6.0
# 1188         7.3     17240.0
# 5132         4.6      4293.0
# 3196         7.1     30772.0
# 1855         5.8     13222.0
# 3046         8.4    131937.0
# 3092         6.5     29318.0
# 219          8.4    434081.0
#
#                                             description
# 836   A spin-off from The Vampire Diaries and set in...
# 3208  Out to avenge his mother's death, a college st...
# 2191  A newly minted military interrogator arrives a...
# 1188  A police officer and a doctor face an emotiona...
# 5132  A wealthy teen and his friends attending an el...
# 3196  Connected by phone in the same home but 20 yea...
# 1855  In the year 2093, a team of scientists aboard ...
# 3046  Terrifying creatures, wicked surprises and dar...
# 3092  In the dark, early days of a zombie apocalypse...
# 219   When they were boys, Sam and Dean Winchester l...

# %%
def top_weighted_by_year(year, df, n=10):
    year_df = df[df['release_year'] == year]
    if year_df.empty:
        return f"No titles found for year {year}."
    
    R = year_df['imdb_score'].fillna(0)
    v = year_df['imdb_votes'].fillna(0)
    C = R.mean()
    m = np.percentile(year_df['imdb_votes'].fillna(0), 80)
    
    weighted_imdb = (v/(v + m)) * R + (m/(v + m)) * C
    year_df = year_df.copy()
    year_df['weighted_score'] = weighted_imdb
    
    top = year_df.sort_values(by='weighted_score', ascending=False)
    
    return top[['title', 'genres', 'release_year', 'imdb_score', 'imdb_votes', 'weighted_score', 'description']].head(n)

# %%
top_weighted_by_year(2008, df, n=10)
# Out:
#                           title  \
# 216                Breaking Bad
# 298                      Ip Man
# 284                      Merlin
# 256             The Hurt Locker
# 280                       Rambo
# 238  The Spectacular Spider-Man
# 412                Jodhaa Akbar
# 495                   Rock On!!
# 334                   Toradora!
# 472     Jaane Tu... Ya Jaane Na
#
#                                                 genres  release_year  \
# 216                     ['drama', 'crime', 'thriller']          2008
# 298  ['drama', 'fantasy', 'comedy', 'history', 'act...          2008
# 284  ['action', 'drama', 'scifi', 'fantasy', 'europ...          2008
# 256                       ['thriller', 'drama', 'war']          2008
# 280          ['action', 'thriller', 'war', 'european']          2008
# 238  ['action', 'animation', 'family', 'scifi', 'co...          2008
# 412   ['romance', 'history', 'war', 'action', 'drama']          2008
# 495                                 ['drama', 'music']          2008
# 334        ['animation', 'comedy', 'drama', 'romance']          2008
# 472                     ['drama', 'comedy', 'romance']          2008
#
#      imdb_score  imdb_votes  weighted_score  \
# 216         9.5   1775990.0        9.444545
# 298         8.0    222372.0        7.782930
# 284         7.9     80927.0        7.433881
# 256         7.5    446904.0        7.416752
# 280         7.0    230333.0        6.905551
# 238         8.3     14996.0        6.886898
# 412         7.5     32440.0        6.866122
# 495         7.7     22092.0        6.825196
# 334         8.0     14828.0        6.782883
# 472         7.4     26894.0        6.757485
#
#                                            description
# 216  When Walter White, a New Mexico chemistry teac...
# 298  A semi-biographical account of Yip Man, the fi...
# 284  The unlikely friendship between Merlin, a youn...
# 256  During the Iraq War, a Sergeant recently assig...
# 280  When governments fail to act on behalf of capt...
# 238  Having spent the summer engaging common crimin...
# 412  Jodhaa Akbar is a sixteenth century love story...
# 495  Aditya, Joe, Kedar and Rob form a rock band, b...
# 334  Ryūji Takasu is a gentle high school student w...
# 472  Two best friends being convinced that they are...
